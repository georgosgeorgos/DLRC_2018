# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
prediction = np.loadtxt("prediction.csv")

# %% [markdown]
# ## 0-400 static
# ## 400-800 static (and dynamic) self
# ## 800-1200 dynamic other

# %%
static, self_, other = 0, 1, 2 
prediction
# Out:
# array([ 2.,  0.,  0., ...,  1.,  0.,  0.])

# %%
prediction.shape
# Out:
# (1200,)

# %%
plt.figure(figsize=(10, 7))
sns.distplot(prediction[0:400])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.distplot(prediction[400:800])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.distplot(prediction[800:1200])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.distplot(prediction)
plt.grid()
plt.show()

# %%
import pickle as pkl
with open("../data/test.pkl", "rb") as f:
        data = np.array(pkl.load(f)[0]["data"])

# %%
data[data > 2000] = 2000

# %%
plt.figure(figsize=(10, 7))
plt.plot(data)
plt.show()

# %%
len(prediction[prediction == 1])
# Out:
# 174

# %%
len(prediction[prediction == 2])
# Out:
# 186

# %%
len(prediction[prediction == 0])
# Out:
# 840
