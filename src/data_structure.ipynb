# %%
import pickle as pkl

# %%
with open("data.pickle", "rb") as f:
    
    data = pkl.load(f)

# %%
data[0].keys()
# Out:
# dict_keys(['trajectory', 'state', 'lidar'])

# %%
data[0]['trajectory'][:10]
# Out:
# [[0.6241293705337396, 0.005117212329845476, 0.5589570230280025],
#  [0.6262911040597239, 0.003387155821435016, 0.5266517342275527],
#  [0.6094904860104595, -0.022294792739922464, 0.4835293585365778],
#  [0.5677277559555702, -0.06402835542548795, 0.4560802069506491],
#  [0.5062529026999931, -0.11050431963591399, 0.45876512572490435],
#  [0.45138207397029956, -0.1373777148327666, 0.4613131263476813],
#  [0.4256522613323032, -0.13657670747877151, 0.4642994067060894],
#  [0.4381261680370595, -0.11335390581122569, 0.45219745318887905],
#  [0.48184607846263117, -0.06298395894197546, 0.4225708688807835],
#  [0.5186570521557107, 0.009559134904062898, 0.39676527412503837]]

# %%
data[0]['state'].keys()
# Out:
# dict_keys(['j_pos', 'j_vel', 'j_load', 'c_pos', 'c_vel', 'c_ori_quat', 'dc_ori_quat', 'timestamp'])

# %%
for key in data[0]['state'].keys():
    
    print(key)
    print(data[0]['state'][key][0])
    print()
# Out:
# j_pos
# [0.0031816025730222464, 0.0050774854607880116, 0.003158863401040435, -1.5549248456954956, 0.006538563407957554, 1.905450701713562, -0.026727154850959778]
#
# j_vel
# [0.0003205666143912822, 0.04766039177775383, -0.001838483614847064, -0.02130727656185627, 0.00022376007109414786, 7.522924079239601e-06, -0.0016185002168640494]
#
# j_load
# [-0.05252683162689209, -29.597854614257812, -0.07329121232032776, 22.341989517211914, 0.6389748454093933, 2.7644622325897217, 0.06847518682479858]
#
# c_pos
# [0.6241293705337396, 0.005117212329845476, 0.5589570230280025]
#
# c_vel
# [0.008868455565327579, -0.0008830953569051592, -0.04125236976389152]
#
# c_ori_quat
# [-0.0014823794053619688, 0.9849890250879344, 0.01575855149012992, 0.17188976339352113]
#
# dc_ori_quat
# [-0.0002384416429779276, 0.005926072918918736, 5.980573840588149e-06, -0.0339610944707807]
#
# timestamp
# 106739.81379341

# %%
data[0]['lidar'].keys()
# Out:
# dict_keys(['measure', 'timestamp'])

# %%
data[0]["lidar"]["measure"]
# Out:
# [[8191, 970, 130, 774, 1255, 8191, 1026, 1224, 1021],
#  [8191, 1002, 109, 745, 1432, 8191, 1037, 1328, 1019],
#  [8191, 1004, 152, 664, 1600, 8191, 1017, 8191, 1028],
#  [8191, 1224, 8190, 119, 1872, 8191, 1003, 8191, 1041],
#  [8191, 8191, 8191, 51, 2006, 1949, 1147, 399, 1096],
#  [2044, 925, 8191, 43, 2138, 8191, 1236, 422, 1202],
#  [8191, 8191, 8191, 47, 2148, 1936, 1195, 374, 1299],
#  [8191, 8191, 8191, 50, 2003, 2167, 1217, 398, 1138],
#  [8191, 8191, 1220, 46, 1788, 2072, 1188, 415, 1053],
#  [8191, 8191, 870, 51, 1201, 8191, 1048, 434, 1020],
#  [8190, 8191, 866, 53, 1087, 1651, 1021, 478, 1033],
#  [8191, 8191, 821, 65, 1015, 8191, 1010, 756, 1028],
#  [8190, 1208, 609, 327, 1052, 8190, 1028, 1123, 1047],
#  [8190, 8191, 193, 652, 1153, 8190, 8191, 1136, 1022],
#  [604, 8191, 897, 668, 1748, 8190, 8191, 938, 1013],
#  [8190, 1065, 279, 680, 1868, 8190, 8191, 888, 1031],
#  [8191, 1116, 249, 685, 1760, 8191, 218, 876, 1023],
# ...
