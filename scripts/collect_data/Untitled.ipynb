# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
with open("./data_0.pkl", "rb") as f:
    data = pickle.load(f)

# %%
lidars = np.array(data[0]["lidar"]["measurements"])
lidars = lidars.astype(float)

# %%
lidars.shape
# Out:
# (201, 9)

# %%
lidars = lidars / 1000
lidars[lidars>2] = 2

# %%
#plt.figure(figsize=(20,10))

for i in range(9):
    plt.plot(lidars[:100,i])
    plt.grid()
    plt.show()
