# %%
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
with open("./clustering_gt.pkl", "rb") as f:
    data = pkl.load(f)

# %%
len(data)
# Out:
# 3

# %%
res = []

for i in range(3):
    res.extend(data[i]["lidar"]["measurements"])

# %%
res = np.array(res)

# %%
res[res > 2000] = 2000

# %%
res.shape
# Out:
# (3000, 9)

# %%
plt.figure(figsize=(20,10))
plt.plot(res[:,3])
plt.grid()
plt.show()

# %%
with open("../experiments/Selector/res_test.json", "rb") as f:
    data = json.load(f)

# %%
y   = np.array(data["y"])[:,3]
mu  = np.array(data["mu"])[:,3]
std = np.array(data["std"])[:,3]
cls = np.array(data["cluster"])[:,3]

# %%
plt.figure(figsize=(20,10))
plt.plot(y)
plt.plot(mu)
plt.ylim([0,1])
# Out:
# (0, 1)
